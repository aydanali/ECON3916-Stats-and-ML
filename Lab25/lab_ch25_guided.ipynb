# %% [markdown]
# <a href="https://colab.research.google.com/github/aydanali/ECON3916-Stats-and-ML/blob/main/Lab25/lab_ch25_guided.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 25: AI Literacy & Generative Tools for Economists
# ## ECON 3916: Data Science for Economists
# ### Guided Construction Lab | 60 min
#
# ---
#
# **Learning Objectives:**
# - Build and deploy a professional portfolio website using AI-assisted development (Claude Code)
# - Practice effective prompt engineering for code generation tasks
# - Document and reflect on the human-AI collaboration process
# - Deploy a live web application via Vercel
#
# **Tools:** Claude Code CLI, Next.js, Vercel, GitHub
#
# **AI Policy:** AI tools are the **point** of this lab. You will use Claude Code actively throughout. The skill being assessed is your ability to *direct* the AI effectively and *evaluate* its output critically.
#
# ---

# %% [markdown]
# ## Part 1: Pre-Lab Setup (GUIDED — 10 min)
#
# Complete these steps **before** the lab session if possible.
#
# ### Step 1: Install Claude Code CLI
#
# Open your terminal and run:
#
# ```bash
# npm install -g @anthropic-ai/claude-code
# ```
#
# Verify the installation:
#
# ```bash
# claude --version
# ```
#
# ### Step 2: Log in with your enterprise account
#
# ```bash
# claude login
# ```
#
# Follow the browser prompts to authenticate. Use your Northeastern credentials if prompted for enterprise SSO.
#
# ### Step 3: Install the portfolio skill
#
# ```bash
# claude skill install /build-portfolio-site
# ```
#
# This skill provides Claude Code with templates and conventions for building portfolio websites.
#
# ### Step 4: Create a Vercel account
#
# 1. Go to [vercel.com](https://vercel.com)
# 2. Click **Sign Up** and choose **Continue with GitHub** (SSO)
# 3. Authorize the Vercel integration with your GitHub account
#
# ### Step 5: Prepare your content
#
# Before building, gather these materials:
#
# - [ ] **Resume or CV** (PDF or text — Claude Code will extract content from it)
# - [ ] **Professional bio** (2-3 sentences about yourself as a data scientist/economist)
# - [ ] **Style reference** from [stitch.withgoogle.com](https://stitch.withgoogle.com) — browse gallery, screenshot 1-2 designs you like
# - [ ] **3+ lab projects** from this course that you want to showcase (repo links, descriptions)
# - [ ] **Professional headshot or avatar** (optional but recommended)

# %% [markdown]
# ## Part 2: Scaffold Your Portfolio Site (GUIDED — 15 min)
#
# Now we use Claude Code to generate the initial site structure. Open your terminal, create a project directory, and launch Claude Code inside it.
#
# ```bash
# mkdir econ-portfolio && cd econ-portfolio
# claude
# ```
#
# ### Prompt 1: Provide your resume and preferences
#
# Paste something like this into the Claude Code session (adapt to YOUR content):
#
# ```
# I want to build a professional portfolio website. Here is my background:
#
# Name: Aydan Ali
# Program: Economics BS, Data Science minor, Northeastern University
# Bio: An economics and data science practitioner with experience spanning commercial analytics and international development finance, I build models that hold up under scrutiny and tell a clear story. From forecasting recessions with yield curve data to detecting fraud with machine learning, my work sits at the intersection of rigorous econometrics and practical data science. I'm always looking for the next hard problem worth solving.
#
# I like the style from this reference: https://www.deepakc.dev/
# It opens with him and his name, stamping his brand, but then breaking into his portfolio. While my portfolio may be less dynamic and more clean, I want to show off my work in a format that attracts attention to my work and skills. I also want people to easily be able to navigate to my work, have it presented in an impressive way, and draw their attention forward to my resume anad contant.
#
# Please scaffold a Next.js portfolio site with:
# - Hero section with my name, bio, and a professional photo placeholder
# - Projects section (I will add 3+ data science projects)
# - Skills section (Python, pandas, scikit-learn, SQL, Plotly, Git)
# - Contact section with email and LinkedIn
# - Clean, responsive design with dark/light mode toggle
# ```
#
# **What to observe:** Watch how Claude Code creates files. It will generate:
# - `package.json` with Next.js dependencies
# - `app/page.tsx` or `pages/index.tsx` with the main layout
# - Component files for each section
# - A `tailwind.config.js` or CSS file for styling
#
# ### Prompt 2: Test the scaffold locally
#
# Ask Claude Code:
# ```
# Install dependencies and start the dev server so I can preview the site.
# ```
#
# Open `http://localhost:3000` in your browser to see the initial site.
#
# **Checkpoint:** You should see a working (but generic) portfolio site with your name and placeholder content.

# %% [markdown]
# ## Part 3: Customize Your Site (YOUR TASK — 20 min)
#
# Now personalize the site with real content from your course projects.
#
# ### Task 3a: Add at least 3 project descriptions
#
# Choose 3 or more labs from this course. For each project, provide Claude Code with:
# - **Project title** (e.g., "Random Forest vs. OLS on California Housing")
# - **1-2 sentence description** of what you did and what you found
# - **GitHub repo link** (from your lab submissions)
# - **Key technologies** used (e.g., scikit-learn, pandas, Plotly)
#
# Example prompt:
# ```
# Add these projects to the Projects section:
#
# 1. Title: "Racial Bias in Hiring: Causal Inference with Probit Regression"
#    Description: Replicated and extended Bertrand & Mullainathan's landmark resume audit study using probit regression on 4,870 observations to quantify the causal effect of race on hiring callbacks. Being white increased callback probability by 49% -- twice the penalty of submitting a low-quality resume -- with near-zero p-value across all robustness checks. Split-sample analysis revealed that credentials like resume quality are nearly invisible for Black applicants, confirming that discrimination operates on both baseline chances and the return to qualifications.
#    GitHub: https://github.com/aydanali/ECON3916-Stats-and-ML/tree/main/Project1
#    Tech: Python, statsmodels, Probit Regression, Marginal Effects, Clustered Standard Errors, Robustness Testing, Causal Inference, pandas, seaborn
#
# 2. Title: "FedSpeak: NLP Analysis of FOMC Minutes"
#    Description: 20+ years of Federal Reserve meeting minutes, analyzed for sentiment shifts and policy uncertainty using TF-IDF, PCA, and K-Means clustering. Unsupervised learning recovered interpretable macro regimes -- no labeled data needed. Post-COVID Fed sentiment never reverted to pre-pandemic levels, pointing to a structural shift in how the FOMC communicates.
#    GitHub: https://github.com/aydanali/ECON3916-Stats-and-ML/tree/main/Lab23
#    Tech: Python, scikit-learn, NLTK, TF-IDF, PCA, K-Means Clustering, Loughran-McDonald Lexicon
#
# 3. Title: "Fraud Detection: Metrics That Matter"
#    Description: Trained a logistic regression classifier on 284,807 real credit card transactions with a 0.17% fraud rate -- where a model predicting zero fraud achieves 99.83% accuracy. Moved beyond accuracy to PR-AUC, ROC-AUC, and threshold sweep analysis to find the true optimal operating point. Applied a real-world business constraint of 500 daily investigations, reframing threshold selection as a resource allocation problem rather than a statistical one.
#    GitHub: https://github.com/aydanali/ECON3916-Stats-and-ML/tree/main/Lab18
#    Tech: Python, scikit-learn, Logistic Regression, PR-AUC, ROC-AUC, Threshold Analysis, pandas, matplotlib, seaborn
#
# Make each project a card with the title, description, tech tags, and a
# link to the GitHub repo. Use a grid layout.
# ```
#
# ### Task 3b: Customize colors and layout
#
# Using your style reference from stitch.withgoogle.com, ask Claude Code to adjust:
# - Color palette-- Dark Mode background: #191D30, primary: #4591B5, accent color: #CC1818. Light Mode use #FAF9F6 as background. Ensure the light/dark mode switch toggles between the two. Use these as jumping points, but feel free to be creative and adjust as needed for design
# - Font choices-- Georgia for type text, Roboto Mono for code
# - Place my headshot, which can be found here: "C:\Users\aydan\OneDrive\Documents\Aydan Ali Resume 4.22.26.pdf"
# - Please link my resume at the hero section. You can find the file here: "C:\Users\aydan\OneDrive\Pictures\headshot_crop.jpeg"
# - Create an interesting  yet simply designed static background for the main landing area.
# - Skills, include Economic and reserach skills that can be thought of from my resume. Don't include R or Bash in Languages.
# - Change Expected Grad in Educations to 2027
#
# ### Task 3c: Add a professional headshot or avatar
#
# Place your image file in the project directory and ask Claude Code to integrate it into the hero section.
#
# *See 3b prompts*
#
# **Document your prompts:** In the reflection below, record which prompts worked well and which needed iteration.

# %% [markdown]
# ## Part 4: Add a Custom Section (YOUR TASK + AI CO-PILOT — 10 min)
#
# Use Claude Code in **co-pilot mode** to add ONE of the following custom sections:
#
# **Option A: "Data Projects" Gallery**
# - A visual gallery with screenshot thumbnails from your lab outputs
# - Hover effects showing project details
# - Filter by technology or topic
#
# **Option B: "Research Interests" Section**
# - A section describing 2-3 economic topics you find interesting
# - Relevant coursework and methods you have learned
# - A "What I am working on" blurb
#
# *Prompt*
# Add a Research and Coursework Section put the following text there that describes my current interests and work
#
# Economic Interests:
#
# The intersection of sociology and economics. How has religion, culture, and social norms shaped economic behavior and institutional development? This sits at the heart of some of the most compelling questions in the field. From Weber's Protestant ethic to modern work on trust and social capital, these dynamics offer a lens that pure markets models often miss.
#
# On the macro side, credit markets, central bank communication, and the transmission of monetary policy captivate me for their real-world stakes. Understanding how the Fed signals intent, how credit cycles amplify shocks, and what the yield curve is actually telling us feels as relevant today as ever.
#
# Econometrics and causal inference round out my core interests -- specifically the challenge of recovering credible estimates from observational data. Probit models, regularization techniques, and the expanding toolkit of machine learning methods all excite me when they're used to answer questions that actually matter.
#
# Relevant Coursework:
#
# Microeconomic Theory, Macroeconomic Theory, Statistics and Machine Learning, Applied Econometrics,
# Statistics for Economists, Managerial Economics, Financial Accounting and Reporting, International Business and Global Social
# Responsibility, Case Studies on Business Strategies & Innovation, International Economics, Economic History of the Middle East,
# Economics of Crime, Religious Influence on Economics, Economics of Crime, Data Science I & II, Foundations of Data Science
#
# What I'm Working On:
#
# Currently finishing up a Statistics and Machine Learning course at Northeastern, where I've been building out an applied econometrics portfolio spanning causal inference, fraud detection, NLP on Fed communications, and regularized forecasting models. Outside the classroom, I co-lead the Northeastern Economics Society and recently organized the Boston Symposium on Economics, a student-run conference bringing together economists, researchers, and practitioners. On the horizon: applying that same mix of economic intuition and technical rigor to my next co-op or internship.
#
# **Option C: "Skills & Tools" Interactive Display**
# - A visual skills chart (bar chart, radar, or icon grid)
# - Categorized by type: Statistics, ML, Data Engineering, Visualization
# - Proficiency levels based on course progression
#
# ### What to document:
# 1. The exact prompts you used
# 2. What Claude Code generated on the first attempt
# 3. What you had to revise or fix manually
# 4. How many prompt iterations it took

# %% [markdown]
# ## Part 5: Deploy to Vercel (YOUR TASK — 10 min)
#
# ### Step 1: Initialize a Git repository and push to GitHub
#
# Ask Claude Code:
# ```
# Initialize a git repo, create a .gitignore for Next.js, and help me
# push this to a new GitHub repository called "econ-portfolio".
# ```
#
# Or do it manually:
# ```bash
# git init
# git add .
# git commit -m "Initial portfolio site"
# gh repo create econ-portfolio --public --push
# ```
#
# ### Step 2: Deploy via Vercel
#
# 1. Go to [vercel.com/new](https://vercel.com/new)
# 2. Import your `econ-portfolio` GitHub repository
# 3. Vercel auto-detects Next.js — click **Deploy**
# 4. Wait ~60 seconds for the build to complete
# 5. Copy your live URL (e.g., `https://econ-portfolio-abc123.vercel.app`)
#
# ### Step 3: Test your live site
#
# - [ ] Open on desktop browser — does everything render correctly?
# - [ ] Open on mobile (or use browser DevTools responsive mode) — is it responsive?
# - [ ] Click all links — do GitHub repo links work?
# - [ ] Check the dark/light mode toggle
#
# **Your live URL:** `https://econ-portfolio-ebon.vercel.app/`

# %% [markdown]
# ## Part 6: Reflection (10 min)
#
# Answer each question in **3-5 sentences**. Connect your answers to concepts from Chapter 25.
#
# ### Q1: What worked well with AI-assisted development?
#
# *Think about: speed of scaffolding, code quality, design suggestions, handling of repetitive tasks.*
#
# **Your answer:** Claude Code was able to handle tasks extremely well. I spoke to it like a normal Claude LLM but with more detail and care about minimizing total prompts and maximizing content. I had no issues with Claude, but it did take a few iterations to get the information on the portfolio correct.
#
#
#
# ### Q2: What did you have to fix manually?
#
# *Think about: layout bugs, incorrect assumptions, styling mismatches, missing features, hallucinated APIs.*
#
# **Your answer:** The biggest issue was the discrepencies between myself and the first few iterations of the portfolio. I needed to correct some information directly. I also gave Claude Code my resume which helped create more accurate descriptions of me. There was some style mismatches, espically when looking at the website as a local file. It was not able to see the designs implimented by Claude and I was surprised to see some things implimented when it went live on Vercel (I did not press the issues because I did not believe it was worth the resources/tokens).
#
#
#
# ### Q3: How does AI-assisted development compare to writing code entirely yourself?
#
# *Think about: the HADI loop from Chapter 25 (Hypothesis, Action, Data, Insight). Did you follow this pattern? Where did you need domain knowledge that the AI lacked?*
#
# **Your answer:** I was skeptical of Claude Code at first, because most projects I've seen developed with Claude Code was done by people with programming and design skills. I believe that AI is limited by its access and creativity rather than knowledge. With my direction, I was able to push Claude Code. I would not have been able to develop and deploy this myself as web development is not my expertise. It would take me several weeks of learning, testing, and iterating to replicate this.
#
#
#
# ### Q4: Prompt engineering lessons
#
# *What makes a good prompt for Claude Code? What makes a bad one? Give one specific example of a prompt you improved.*
#
# **Your answer:** A good prompt includes clear context, direction, and output thought. Claude Code is limited by tokens (and other resources), so it is important to do thoughtful and reasoned prompts. The biggest improvements of prompting I ran into was the given example prompts. I found them to be very general and gives too much room for interpretation, which is where Claude would run into issues. For instance, instead of giving normal color combinations, I gave HEX numbers to allow Claude a stronger direction in the primary colors. After giving that, it was able to stylize well.
#
#
#
# ### Q5: If you were hiring a junior data scientist, would their portfolio site influence your evaluation? Why or why not?
#
# *Connect to the "signaling" concept from labor economics — what does a portfolio signal that a resume alone does not?*
#
# **Your answer:** I believe that a portfolio site would influence my decision. Building it from scratch is impressive, but utilizing AI is important. Being able to develop a strong portfolio site that markets you correctly is key for data scientists. It is really easy to throw together a basic and minimal portfolio with AI in a hour or so with minimal knowledge of the skills need without AI (I did so, and I feel like I could even teach my Mom to). When looking at others' "Vibe Coded" portfolio, I saw extremely well designed, dynamic, powerful portfolios (example is the link I said inspired me). Creating something like that requires more time, expertise, and skill than a basic portfolio.

# %% [markdown]
# ---
#
# ## Submission
#
# Submit the following on Canvas:
#
# 1. **Deployed portfolio URL** (Vercel link)
# 2. **This notebook** with all reflection questions answered
# 3. **GitHub repository link** for the portfolio source code
#
# ```bash
# # Final push
# cd econ-portfolio
# git add .
# git commit -m "Lab 25: AI-assisted portfolio site"
# git push origin main
# ```
#
# Submit your Vercel URL and GitHub repo link on Canvas.
